# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

lpd_group = pd.read_csv('files/lpd_group_rectified.csv')
control_group = pd.read_csv('files/english_control_group.csv')

# %%
lpd_group.head()
# Out:
#    Subject  avg_ld_eng  anagrams_eng  ml_migrations_eng  el_migrations_eng  \
# 0     5.12       0.783            21                 18                  3
# 1     5.13       1.083            27                 24                  3
# 2     5.16       0.733            19                 17                  2
# 3     5.18       1.083            21                 18                  3
# 4     4.16       1.000            22                 20                  2
#
#    avg_ld_ben  anagrams_ben  ml_migrations_ben  el_migrations_ben
# 0       0.933             9                  0                  9
# 1       0.816            14                  1                 13
# 2       0.566            10                  2                  8
# 3       0.783             9                  1                  8
# 4       0.850            11                  1                 10

# %%
control_group.head()
# Out:
#    subject  avg_ld_eng  anagrams_eng  ml_migrations_eng  el_migrations_eng  \
# 0     5.30       0.383             4                  3                  1
# 1     5.11       0.516             8                  7                  1
# 2     5.15       0.333             7                  5                  2
# 3     4.12       0.233             6                  5                  1
# 4     4.13       0.400             8                  8                  0
#
#    avg_ld_ben  anagrams_ben  ml_migrations_ben  el_migrations_ben
# 0       0.616             5                  1                  4
# 1       0.283             2                  1                  1
# 2       0.283             0                  0                  0
# 3       0.550             2                  0                  2
# 4       0.483             3                  0                  3

# %% [markdown]
# ## Distribution of the data

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
sns.distplot(lpd_group['anagrams_eng'])
sns.distplot(control_group['anagrams_eng'])
plt.legend(["LPD Group", "Control group"])
plt.xlabel("Number of anagrams pronounced in English")
plt.title("Distribution of anagrams pronounced in English")

plt.subplot(1, 2, 2)
sns.distplot(lpd_group['anagrams_ben'])
sns.distplot(control_group['anagrams_ben'])
plt.legend(["LPD Group", "Control group"])
plt.xlabel("Number of anagrams pronounced in Bengali")
plt.title("Distribution of anagrams pronounced in Bengali")

plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
sns.distplot(lpd_group['ml_migrations_eng'])
sns.distplot(control_group['ml_migrations_eng'])
plt.legend(["LPD Group", "Control group"])
plt.xlabel("Number of middle letter migrations pronounced in English")
plt.title("Distribution of middle letter migrations pronounced in English")

plt.subplot(1, 2, 2)
sns.distplot(lpd_group['ml_migrations_ben'])
sns.distplot(control_group['ml_migrations_ben'])
plt.legend(["LPD Group", "Control group"])
plt.xlabel("Number of middle letter migrations pronounced in Bengali")
plt.title("Distribution of middle letter migrations pronounced in Bengali")

plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
sns.distplot(lpd_group['el_migrations_eng'])
sns.distplot(control_group['el_migrations_eng'])
plt.legend(["LPD Group", "Control group"])
plt.xlabel("Number of exterior letter migrations pronounced in English")
plt.title("Distribution of exterior letter migrations pronounced in English")

plt.subplot(1, 2, 2)
sns.distplot(lpd_group['el_migrations_ben'])
sns.distplot(control_group['el_migrations_ben'])
plt.legend(["LPD Group", "Control group"])
plt.xlabel("Number of exterior letter migrations pronounced in Bengali")
plt.title("Distribution of exterior letter migrations pronounced in Bengali")

plt.show()

# %% [markdown]
# ## Numerical analysis of the data

# %%
import numpy as np

lpd_anagrams_english_mean = np.mean(lpd_group['anagrams_eng'].values)
control_anagrams_english_mean = np.mean(control_group['anagrams_eng'].values)

print("Mean anagrams pronounced in English by lpd group subjects = %.2f" % (lpd_anagrams_english_mean))
print("Mean anagrams pronounced in English by control group subjects = %.2f" % (control_anagrams_english_mean))

lpd_anagrams_english_std = np.std(lpd_group['anagrams_eng'].values)
control_anagrams_english_std = np.std(control_group['anagrams_eng'].values)

print("Standard deviation of anagrams pronounced in English by lpd group subjects = %.2f" % (lpd_anagrams_english_std))
print("Standard deviation of anagrams pronounced in English by control group subjects = %.2f" % (control_anagrams_english_std))
# Out:
# Mean anagrams pronounced in English by lpd group subjects = 22.25
# Mean anagrams pronounced in English by control group subjects = 6.88
# Standard deviation of anagrams pronounced in English by lpd group subjects = 3.68
# Standard deviation of anagrams pronounced in English by control group subjects = 1.27

# %%
lpd_ml_migrations_english_mean = np.mean(lpd_group['ml_migrations_eng'].values)
control_ml_migrations_english_mean = np.mean(control_group['ml_migrations_eng'].values)

print("Mean number of middle letter migrations pronounced in English by lpd group subjects = %.2f" % (lpd_ml_migrations_english_mean))
print("Mean number of middle letter migrations pronounced in English by control group subjects = %.2f" % (control_ml_migrations_english_mean))

lpd_ml_migrations_english_std = np.std(lpd_group['ml_migrations_eng'].values)
control_ml_migrations_english_std = np.std(control_group['ml_migrations_eng'].values)

print("Standard deviation of middle letter migrations pronounced in English by lpd group subjects = %.2f" % (lpd_ml_migrations_english_std))
print("Standard deviation of middle letter migrations pronounced in English by control group subjects = %.2f" % (control_ml_migrations_english_std))
# Out:
# Mean number of middle letter migrations pronounced in English by lpd group subjects = 19.33
# Mean number of middle letter migrations pronounced in English by control group subjects = 5.75
# Standard deviation of middle letter migrations pronounced in English by lpd group subjects = 3.25
# Standard deviation of middle letter migrations pronounced in English by control group subjects = 1.48

# %%
lpd_el_migrations_english_mean = np.mean(lpd_group['el_migrations_eng'].values)
control_el_migrations_english_mean = np.mean(control_group['el_migrations_eng'].values)

print("Mean number of exterior letter migrations pronounced in English by lpd group subjects = %.2f" % (lpd_el_migrations_english_mean))
print("Mean number of exterior letter migrations pronounced in English by control group subjects = %.2f" % (control_el_migrations_english_mean))

lpd_el_migrations_english_std = np.std(lpd_group['el_migrations_eng'].values)
control_el_migrations_english_std = np.std(control_group['el_migrations_eng'].values)

print("Standard deviation of exterior letter migrations pronounced in English by lpd group subjects = %.2f" % (lpd_el_migrations_english_std))
print("Standard deviation of exterior letter migrations pronounced in English by control group subjects = %.2f" % (control_el_migrations_english_std))
# Out:
# Mean number of exterior letter migrations pronounced in English by lpd group subjects = 2.92
# Mean number of exterior letter migrations pronounced in English by control group subjects = 1.12
# Standard deviation of exterior letter migrations pronounced in English by lpd group subjects = 0.86
# Standard deviation of exterior letter migrations pronounced in English by control group subjects = 0.60

# %% [markdown]
# ## Two sampled t-test

# %% [markdown]
# **Null hypothesis:** The number of anagrams pronounced by the LPD group in bengali have a similar mean as the number of anagrams pronounced by the control group (mean difference is 0).

# %%
from scipy.stats import ttest_ind

ttest, pval = ttest_ind(lpd_group['anagrams_eng'].values, control_group['anagrams_eng'].values)
print("p-value for T-test = %.2f" % (pval))

if pval <= 0.05:
    print("We reject null hypothesis")
    print("There is significant difference between means of anagrams pronounced by the two groups")
else:
    print("We accept null hypothesis")
    print("There is no significant difference between means of anagrams pronounced by the two groups")
# Out:
# p-value for T-test = 0.00
# We reject null hypothesis
# There is significant difference between means of anagrams pronounced by the two groups

# %% [markdown]
# **Null hypothesis:** The number of middle letter migrations pronounced by the LPD group in bengali have a similar mean as the number of middle letter migrations pronounced by the control group (mean difference is 0).

# %%
ttest, pval = ttest_ind(lpd_group['ml_migrations_eng'].values, control_group['ml_migrations_eng'].values)
print("p-value for T-test = %.2f" % (pval))

if pval <= 0.05:
    print("We reject null hypothesis")
    print("There is significant difference between means of middle letter migrations pronounced by the two groups")
else:
    print("We accept null hypothesis")
    print("There is no significant difference between means of middle letter migrations pronounced by the two groups")
# Out:
# p-value for T-test = 0.00
# We reject null hypothesis
# There is significant difference between means of middle letter migrations pronounced by the two groups

# %% [markdown]
# **Null hypothesis:** The number of exterior letter migrations pronounced by the LPD group in bengali have a similar mean as the number of exterior letter migrations pronounced by the control group (mean difference is 0).

# %%
ttest, pval = ttest_ind(lpd_group['el_migrations_eng'].values, control_group['el_migrations_eng'].values)
print("p-value for T-test = %.2f" % (pval))

if pval <= 0.05:
    print("We reject null hypothesis")
    print("There is significant difference between means of exterior letter migrations pronounced by the two groups")
else:
    print("We accept null hypothesis")
    print("There is no significant difference between means of exterior letter migrations pronounced by the two groups")
# Out:
# p-value for T-test = 0.00
# We reject null hypothesis
# There is significant difference between means of exterior letter migrations pronounced by the two groups

# %% [markdown]
# ## One-sampled t-test

# %%
from scipy.stats import ttest_1samp

anagrams_p = []
for num in control_group['anagrams_eng']:
    ttest, pval = ttest_1samp(lpd_group['anagrams_eng'], num)
    anagrams_p.append(pval)
    
ml_migrations_p = []
for num in control_group['ml_migrations_eng']:
    ttest, pval = ttest_1samp(lpd_group['ml_migrations_eng'], num)
    ml_migrations_p.append(pval)
    
el_migrations_p = []
for num in control_group['el_migrations_eng']:
    ttest, pval = ttest_1samp(lpd_group['el_migrations_eng'], num)
    el_migrations_p.append(pval)
    
result_data = pd.DataFrame.from_dict({
    'subject': control_group['subject'].values,
    'anagrams_pvalue': anagrams_p,
    'ml_migrations_pvalue': ml_migrations_p,
    'el_migrations_pvalue': el_migrations_p
})
result_data
# Out:
#    subject  anagrams_pvalue  ml_migrations_pvalue  el_migrations_pvalue
# 0     5.30     4.268323e-09          3.725068e-09          1.404223e-05
# 1     5.11     5.724861e-08          7.090336e-08          1.404223e-05
# 2     5.15     2.826837e-08          1.479839e-08          4.740328e-03
# 3     4.12     1.453413e-08          1.479839e-08          1.404223e-05
# 4     4.13     5.724861e-08          1.691965e-07          2.309567e-07
# 5     4.70     5.724861e-08          7.090336e-08          1.404223e-05
# 6     3.53     2.826837e-08          1.479839e-08          4.740328e-03
# 7     3.55     2.826837e-08          3.154956e-08          1.404223e-05
